# %%
from bs4 import BeautifulSoup
import requests

# %%
"""
espol = requests.get('http://www.espol.edu.ec')
print(espol.status_code)
print(espol.content[:200])#slicing: desde que inicia hasta el caracter 200
if "<table>" in espol.content:
    print("tiene tablas")
print(espol.headers)
print(espol.cookies.items())


Extract ALL of the locations from Icee's website via this page
http://www.icee.com/locationsICEE.asp
"""

# %%
for i in range (15:40):
    states = ['AK']
    my_list.append()

# %%
for state in states:
    stateSelection = "https://www.eluniverso.com/tema/crisis-venezuela?page=%s" % state
    r = requests.get(stateSelection)
    soup = BeautifulSoup(r.text, "html.parser")
    rows = soup.find_all("option")
    cities = [row.attrs['value'] for row in rows]#list comprehensions -> Cities=[] for row in rows: cities.append(row.attrs[value])
    print(end='\n')
    print("Cities with locations on the state of %s : " % state)
    print(cities)
    i=1
    print("\n\nHtml del resultado de la busqueda en todas las ciudades")
    for city in cities:
        data = {'city': city, 'state': state, 'submit': 'submit'}
        url = "http://www.icee.com/locationsresults.asp"
        req = requests.get(url, data=data)
        print(i)
        soup2 = BeautifulSoup(req.text, "html.parser")
        print(soup2)
        i += 1
        print(end='\n')
        print("tds")
        for page in soup2:
            celdas = soup2.find_all("td",{"class":"order_table2"})
            print("-----------------")
            print(celdas)
            print(end='\n')
            print("Direccion")
            interes = [celda.getText()for celda in celdas]
            print(interes[6])
# Out:
# Cities with locations on the state of AK :
# ['ANCHORAGE', 'FAIRBANKS']
#
#
# Html del resultado de la busqueda en todas las ciudades
# 1
#
# <html>
# <head>
# <title>Stores</title>
# <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>
# <link href="icee.css" rel="stylesheet" type="text/css"/>
# </head>
# <body bgcolor="#FFFFFF" leftmargin="0" marginheight="0" marginwidth="0" text="#000000" topmargin="0">
# <table align="center" bgcolor="#bfe2f8" border="0" cellpadding="0" cellspacing="0" height="100%" width="600">
# <tr>
# <td height="1" rowspan="2" width="1"> </td>
# <td align="left" class="PR_headline" height="1" valign="middle"> </td>
# </tr>
# <tr>
# <td align="left" height="10" valign="top">
# <table border="0" cellpadding="0" cellspacing="0" height="89" width="100%">
# <tr>
# <td colspan="3" height="180"><img border="0" src="images/LocationHeader.gif"/></td>
# </tr>
# <tr>
# <td height="87" width="3%"> </td>
# <td class="popUp_text4" height="87" width="47%"> Here is a list of where
#             you can find ICEEs/Arctic Blast in your area. </td>
# <td height="87" width="50%"> </td>
# </tr>
# </table>
# </td>
# </tr>
# <tr>
# <td height="24" width="1"> </td>
# <td align="left" rowspan="7" valign="top">
# <table border="0" cellpadding="0" cellspacing="0" height="200" width="600">
# <tr>
# <td class="order_table2" width="222"><font face="Verdana, Arial, Helvetica, sans-serif" size="2">Store
# 									Name</font></td>
# <td class="order_table2" width="31"><font size="2">Product</font></td>
# <td class="order_table2" width="179"><font size="2">Address</font></td>
# <td class="order_table2" width="167"><font size="2">City - Zip</font></td>
# </tr>
# <tr>
# <td class="order_table2" width="222">
# <a href="http://www.mapquest.com/maps/map.adp?city=ANCHORAGE&amp;state=AK&amp;address=1074 N MULDOON RD&amp;zip=99504&amp;country=us&amp;zoom=5" target="_blank">
# 							SAMS CLUB
# 							</a>
# <br/>
# </td>
# <td class="order_table2" width="31"> </td>
# <td class="order_table2" width="179">1074 N MULDOON RD STORE: 6602</td>
# <td class="order_table2" width="167">ANCHORAGE - 99504</td>
# </tr>
# <tr>
# <td class="order_table2" colspan="5"><a href="locations.asp">back</a></td>
# </tr>
# </table>
# </td>
# </tr>
# <tr>
# <td height="24" width="1"> </td>
# </tr>
# <tr>
# <td height="24" width="1"> </td>
# </tr>
# <tr>
# <td height="24" width="1"> </td>
# </tr>
# <tr>
# <td height="24" width="1"> </td>
# </tr>
# <tr>
# <td height="24" width="1"> </td>
# </tr>
# <tr>
# <td height="24" width="1"> </td>
# </tr>
# <tr>
# <td width="1"> </td>
# <td align="left" valign="middle">
# <table border="0" cellpadding="0" cellspacing="0" width="100%">
# <tr>
# <td bgcolor="#333333" height="2" width="95%">
# <div align="right"><img height="21" src="images/pu_left.jpg" width="215"/><a href="#" onclick="window.print();return false"><img alt="" border="0" height="21" src="images/pu_print.jpg" width="76"/></a><a href="javascript:void(0)" onclick="self.close();return false"><img alt="" border="0" height="21" src="images/pu_close.jpg" width="67"/></a><a href="javascript:window.close();"></a></div>
# </td>
# <td bgcolor="#333333" class="PR_headline" height="2" width="5%"> </td>
# </tr>
# </table>
# </td>
# </tr>
# </table>
# </body>
# </html>
#
#
# tds
# -----------------
# [<td class="order_table2" width="222"><font face="Verdana, Arial, Helvetica, sans-serif" size="2">Store
# 									Name</font></td>, <td class="order_table2" width="31"><font size="2">Product</font></td>, <td class="order_table2" width="179"><font size="2">Address</font></td>, <td class="order_table2" width="167"><font size="2">City - Zip</font></td>, <td class="order_table2" width="222">
# <a href="http://www.mapquest.com/maps/map.adp?city=ANCHORAGE&amp;state=AK&amp;address=1074 N MULDOON RD&amp;zip=99504&amp;country=us&amp;zoom=5" target="_blank">
# 							SAMS CLUB
# 							</a>
# <br/>
# </td>, <td class="order_table2" width="31"> </td>, <td class="order_table2" width="179">1074 N MULDOON RD STORE: 6602</td>, <td class="order_table2" width="167">ANCHORAGE - 99504</td>, <td class="order_table2" colspan="5"><a href="locations.asp">back</a></td>]
#
# Direccion
# 1074 N MULDOON RD STORE: 6602
# -----------------
# [<td class="order_table2" width="222"><font face="Verdana, Arial, Helvetica, sans-serif" size="2">Store
# 									Name</font></td>, <td class="order_table2" width="31"><font size="2">Product</font></td>, <td class="order_table2" width="179"><font size="2">Address</font></td>, <td class="order_table2" width="167"><font size="2">City - Zip</font></td>, <td class="order_table2" width="222">
# <a href="http://www.mapquest.com/maps/map.adp?city=ANCHORAGE&amp;state=AK&amp;address=1074 N MULDOON RD&amp;zip=99504&amp;country=us&amp;zoom=5" target="_blank">
# 							SAMS CLUB
# 							</a>
# <br/>
# </td>, <td class="order_table2" width="31"> </td>, <td class="order_table2" width="179">1074 N MULDOON RD STORE: 6602</td>, <td class="order_table2" width="167">ANCHORAGE - 99504</td>, <td class="order_table2" colspan="5"><a href="locations.asp">back</a></td>]
#
# Direccion
# 1074 N MULDOON RD STORE: 6602
# -----------------
# [<td class="order_table2" width="222"><font face="Verdana, Arial, Helvetica, sans-serif" size="2">Store
# 									Name</font></td>, <td class="order_table2" width="31"><font size="2">Product</font></td>, <td class="order_table2" width="179"><font size="2">Address</font></td>, <td class="order_table2" width="167"><font size="2">City - Zip</font></td>, <td class="order_table2" width="222">
# <a href="http://www.mapquest.com/maps/map.adp?city=ANCHORAGE&amp;state=AK&amp;address=1074 N MULDOON RD&amp;zip=99504&amp;country=us&amp;zoom=5" target="_blank">
# 							SAMS CLUB
# 							</a>
# <br/>
# </td>, <td class="order_table2" width="31"> </td>, <td class="order_table2" width="179">1074 N MULDOON RD STORE: 6602</td>, <td class="order_table2" width="167">ANCHORAGE - 99504</td>, <td class="order_table2" colspan="5"><a href="locations.asp">back</a></td>]
#
# Direccion
# 1074 N MULDOON RD STORE: 6602
# 2
#
# <html>
# <head>
# <title>Stores</title>
# <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>
# <link href="icee.css" rel="stylesheet" type="text/css"/>
# </head>
# <body bgcolor="#FFFFFF" leftmargin="0" marginheight="0" marginwidth="0" text="#000000" topmargin="0">
# <table align="center" bgcolor="#bfe2f8" border="0" cellpadding="0" cellspacing="0" height="100%" width="600">
# <tr>
# <td height="1" rowspan="2" width="1"> </td>
# <td align="left" class="PR_headline" height="1" valign="middle"> </td>
# </tr>
# <tr>
# <td align="left" height="10" valign="top">
# <table border="0" cellpadding="0" cellspacing="0" height="89" width="100%">
# <tr>
# <td colspan="3" height="180"><img border="0" src="images/LocationHeader.gif"/></td>
# </tr>
# <tr>
# <td height="87" width="3%"> </td>
# <td class="popUp_text4" height="87" width="47%"> Here is a list of where
#             you can find ICEEs/Arctic Blast in your area. </td>
# <td height="87" width="50%"> </td>
# </tr>
# </table>
# </td>
# </tr>
# <tr>
# <td height="24" width="1"> </td>
# <td align="left" rowspan="7" valign="top">
# <table border="0" cellpadding="0" cellspacing="0" height="200" width="600">
# <tr>
# <td class="order_table2" width="222"><font face="Verdana, Arial, Helvetica, sans-serif" size="2">Store
# 									Name</font></td>
# <td class="order_table2" width="31"><font size="2">Product</font></td>
# <td class="order_table2" width="179"><font size="2">Address</font></td>
# <td class="order_table2" width="167"><font size="2">City - Zip</font></td>
# </tr>
# <tr>
# <td class="order_table2" width="222">
# <a href="http://www.mapquest.com/maps/map.adp?city=FAIRBANKS&amp;state=AK&amp;address=48 COLLEGE RD&amp;zip=99701&amp;country=us&amp;zoom=5" target="_blank">
# 							SAMS CLUB
# 							</a>
# <br/>
# </td>
# <td class="order_table2" width="31"> </td>
# <td class="order_table2" width="179">48 COLLEGE RD </td>
# <td class="order_table2" width="167">FAIRBANKS - 99701</td>
# </tr>
# <tr>
# <td class="order_table2" colspan="5"><a href="locations.asp">back</a></td>
# </tr>
# </table>
# </td>
# </tr>
# <tr>
# <td height="24" width="1"> </td>
# </tr>
# <tr>
# <td height="24" width="1"> </td>
# </tr>
# <tr>
# <td height="24" width="1"> </td>
# </tr>
# <tr>
# <td height="24" width="1"> </td>
# </tr>
# <tr>
# <td height="24" width="1"> </td>
# </tr>
# <tr>
# <td height="24" width="1"> </td>
# </tr>
# <tr>
# <td width="1"> </td>
# <td align="left" valign="middle">
# <table border="0" cellpadding="0" cellspacing="0" width="100%">
# <tr>
# <td bgcolor="#333333" height="2" width="95%">
# <div align="right"><img height="21" src="images/pu_left.jpg" width="215"/><a href="#" onclick="window.print();return false"><img alt="" border="0" height="21" src="images/pu_print.jpg" width="76"/></a><a href="javascript:void(0)" onclick="self.close();return false"><img alt="" border="0" height="21" src="images/pu_close.jpg" width="67"/></a><a href="javascript:window.close();"></a></div>
# </td>
# <td bgcolor="#333333" class="PR_headline" height="2" width="5%"> </td>
# </tr>
# </table>
# </td>
# </tr>
# </table>
# </body>
# </html>
#
#
# tds
# -----------------
# [<td class="order_table2" width="222"><font face="Verdana, Arial, Helvetica, sans-serif" size="2">Store
# 									Name</font></td>, <td class="order_table2" width="31"><font size="2">Product</font></td>, <td class="order_table2" width="179"><font size="2">Address</font></td>, <td class="order_table2" width="167"><font size="2">City - Zip</font></td>, <td class="order_table2" width="222">
# <a href="http://www.mapquest.com/maps/map.adp?city=FAIRBANKS&amp;state=AK&amp;address=48 COLLEGE RD&amp;zip=99701&amp;country=us&amp;zoom=5" target="_blank">
# 							SAMS CLUB
# 							</a>
# <br/>
# </td>, <td class="order_table2" width="31"> </td>, <td class="order_table2" width="179">48 COLLEGE RD </td>, <td class="order_table2" width="167">FAIRBANKS - 99701</td>, <td class="order_table2" colspan="5"><a href="locations.asp">back</a></td>]
#
# Direccion
# 48 COLLEGE RD
# -----------------
# [<td class="order_table2" width="222"><font face="Verdana, Arial, Helvetica, sans-serif" size="2">Store
# 									Name</font></td>, <td class="order_table2" width="31"><font size="2">Product</font></td>, <td class="order_table2" width="179"><font size="2">Address</font></td>, <td class="order_table2" width="167"><font size="2">City - Zip</font></td>, <td class="order_table2" width="222">
# <a href="http://www.mapquest.com/maps/map.adp?city=FAIRBANKS&amp;state=AK&amp;address=48 COLLEGE RD&amp;zip=99701&amp;country=us&amp;zoom=5" target="_blank">
# 							SAMS CLUB
# 							</a>
# <br/>
# </td>, <td class="order_table2" width="31"> </td>, <td class="order_table2" width="179">48 COLLEGE RD </td>, <td class="order_table2" width="167">FAIRBANKS - 99701</td>, <td class="order_table2" colspan="5"><a href="locations.asp">back</a></td>]
#
# Direccion
# 48 COLLEGE RD
# -----------------
# [<td class="order_table2" width="222"><font face="Verdana, Arial, Helvetica, sans-serif" size="2">Store
# 									Name</font></td>, <td class="order_table2" width="31"><font size="2">Product</font></td>, <td class="order_table2" width="179"><font size="2">Address</font></td>, <td class="order_table2" width="167"><font size="2">City - Zip</font></td>, <td class="order_table2" width="222">
# <a href="http://www.mapquest.com/maps/map.adp?city=FAIRBANKS&amp;state=AK&amp;address=48 COLLEGE RD&amp;zip=99701&amp;country=us&amp;zoom=5" target="_blank">
# 							SAMS CLUB
# 							</a>
# <br/>
# </td>, <td class="order_table2" width="31"> </td>, <td class="order_table2" width="179">48 COLLEGE RD </td>, <td class="order_table2" width="167">FAIRBANKS - 99701</td>, <td class="order_table2" colspan="5"><a href="locations.asp">back</a></td>]
#
# Direccion
# 48 COLLEGE RD
